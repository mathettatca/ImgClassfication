# %% [markdown]
# <a href="https://colab.research.google.com/github/mathettatca/ImgClassfication/blob/main/w06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML - DL - Train/Validate/Test - Lauch

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
from sklearn import linear_model

# %%
! pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in f:\allsoftwares\anaconda\lib\site-packages (1.3.0)
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/a1/a6/c5b78606743a1f28eae8f11973de6613a5ee87366796583fb74c67d54939/scikit_learn-1.6.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading scikit_learn-1.6.1-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in f:\allsoftwares\anaconda\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.6.0 in f:\allsoftwares\anaconda\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.2.0 in f:\allsoftwares\anaconda\lib\site-packages (from scikit-learn) (1.2.0)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Obtaining dependency information for threadpoolctl>=3.1.0 from https://files.pythonhosted.org/packages/32/d5/f9a850d79b0851d1d4ef6456097579a9005b31fea68726a4ae5f2d82ddd9/threadpoolctl-3.6.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp311-cp311-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB 1.4 MB/s eta 0:00:09
#    ---------------------------------------- 0.1/11.1 MB 787.7 kB/s eta 0:00:15
#    ---------------------------------------- 0.1/11.1 MB 787.7 kB/s eta 0:00:15
#     --------------------------------------- 0.2/11.1 MB 1.0 MB/s eta 0:00:11
#     --------------------------------------- 0.3/11.1 MB 1.1 MB/s eta 0:00:10
#    - -------------------------------------- 0.4/11.1 MB 1.5 MB/s eta 0:00:08
#    - -------------------------------------- 0.5/11.1 MB 1.7 MB/s eta 0:00:07
#    -- ------------------------------------- 0.7/11.1 MB 1.9 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/11.1 MB 2.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/11.1 MB 3.0 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.4/11.1 MB 3.0 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.4/11.1 MB 3.0 MB/s eta 0:00:04
#    -------- ------------------------------- 2.5/11.1 MB 4.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.9/11.1 MB 4.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.2/11.1 MB 4.6 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.1 MB 4.7 MB/s eta 0:00:02
#    ------------- -------------------------- 3.7/11.1 MB 4.7 MB/s eta 0:00:02
#    ------------- -------------------------- 3.8/11.1 MB 4.6 MB/s eta 0:00:02
#    -------------- ------------------------- 4.1/11.1 MB 4.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.5/11.1 MB 4.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.8/11.1 MB 4.8 MB/s eta 0:00:02
#    ------------------- -------------------- 5.3/11.1 MB 5.1 MB/s eta 0:00:02
#    ------------------- -------------------- 5.3/11.1 MB 4.9 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.1 MB 5.0 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.1 MB 5.0 MB/s eta 0:00:02
#    ------------------- -------------------- 5.5/11.1 MB 5.0 MB/s eta 0:00:02
#    -------------------- ------------------- 5.8/11.1 MB 4.7 MB/s eta 0:00:02
#    -------------------- ------------------- 5.8/11.1 MB 4.6 MB/s eta 0:00:02
#    --------------------- ------------------ 6.0/11.1 MB 4.5 MB/s eta 0:00:02
#    --------------------- ------------------ 6.0/11.1 MB 4.4 MB/s eta 0:00:02
#    --------------------- ------------------ 6.1/11.1 MB 4.3 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.3/11.1 MB 4.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.4/11.1 MB 4.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.5/11.1 MB 4.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.6/11.1 MB 4.2 MB/s eta 0:00:02
#    ------------------------ --------------- 6.8/11.1 MB 4.2 MB/s eta 0:00:02
#    ------------------------- -------------- 7.1/11.1 MB 4.1 MB/s eta 0:00:01
#    ------------------------- -------------- 7.2/11.1 MB 4.2 MB/s eta 0:00:01
#    --------------------------- ------------ 7.6/11.1 MB 4.2 MB/s eta 0:00:01
#    --------------------------- ------------ 7.7/11.1 MB 4.2 MB/s eta 0:00:01
#    --------------------------- ------------ 7.8/11.1 MB 4.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.9/11.1 MB 4.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.1/11.1 MB 4.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.1/11.1 MB 4.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.3/11.1 MB 4.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.3/11.1 MB 4.0 MB/s eta 0:00:01
#    ------------------------------ --------- 8.4/11.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------ --------- 8.5/11.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------ --------- 8.6/11.1 MB 3.8 MB/s eta 0:00:01
#    ------------------------------ --------- 8.6/11.1 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.1 MB 3.7 MB/s eta 0:00:01
#    ------------------------------- -------- 8.8/11.1 MB 3.7 MB/s eta 0:00:01
#    -------------------------------- ------- 8.9/11.1 MB 3.7 MB/s eta 0:00:01
#    -------------------------------- ------- 9.0/11.1 MB 3.7 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.1 MB 3.7 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.1 MB 3.7 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.1 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.6/11.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.7/11.1 MB 3.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.8/11.1 MB 3.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.9/11.1 MB 3.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.9/11.1 MB 3.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.1 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.1 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.1/11.1 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.1/11.1 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.1/11.1 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.1 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.1 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 10.4/11.1 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.1 MB 3.5 MB/s eta 0:00:01
#    -------------------------------------- - 10.8/11.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  11.1/11.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  11.1/11.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 3.4 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scikit-learn
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 2.2.0
#     Uninstalling threadpoolctl-2.2.0:
#       Successfully uninstalled threadpoolctl-2.2.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.0
#     Uninstalling scikit-learn-1.3.0:
#       Successfully uninstalled scikit-learn-1.3.0
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'F:\\AllSoftwares\\Anaconda\\Lib\\site-packages\\~klearn\\linear_model\\_cd_fast.cp311-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %%
dulieu = pd.read_csv("./data/data-RealEstateDataset.csv")

# %%
dulieu.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
sns.heatmap( dulieu.corr() )
# Out:
# <Axes: >

# %%
X = dulieu[['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX']]
y = dulieu['MEDV']

mohinh = linear_model.LinearRegression()
mohinh.fit(X, y)
# Out:
# LinearRegression()

# %%
mohinh.coef_  ,  mohinh.intercept_
# Out:
# (array([-0.22816218,  0.0513729 , -0.37564782,  6.82303181, -5.75079824]),
#  29.83373393488261)

# %%
yPredict = mohinh.predict(X)

# %%
plt.scatter(y, yPredict)

yx = [0, max(y.max(), yPredict.max())]
plt.plot( yx, yx,c="red" )

plt.show()

# %% [markdown]
# ## TRain - Test split

# %%
x = np.random.normal(3, 1, 100)
y = np.random.normal(150, 40, 100) / x

plt.scatter(x, y)
plt.show()

# %%
## split

train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

train_x.shape , train_y.shape
# Out:
# ((80,), (80,))

# %%
plt.scatter(test_x, test_y)
plt.show()

# %%
mymodel = np.poly1d( np.polyfit(train_x, train_y, 3) )

myline = np.linspace(0, 6, 100)

plt.scatter(train_x, train_y)
plt.plot(myline, mymodel(myline), c="r")
plt.show()

# %%
from sklearn.metrics import r2_score

# %%
r2_train = r2_score(train_y, mymodel(train_x))

r2_train
# Out:
# 0.707313056298672

# %%
r2_test = r2_score(test_y, mymodel(test_x))

r2_test
# Out:
# 0.8561380933629432

# %% [markdown]
# ## Tensorflow + Keras - Image Classify !!!
# - pip install tensorflow

# %%
! pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in f:\allsoftwares\anaconda\lib\site-packages (2.14.0)
# Requirement already satisfied: tensorflow-intel==2.14.0 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.24.4)
# Requirement already satisfied: setuptools in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (1.59.2)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in f:\allsoftwares\anaconda\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in f:\allsoftwares\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.14.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in f:\allsoftwares\anaconda\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.23.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in f:\allsoftwares\anaconda\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in f:\allsoftwares\anaconda\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in f:\allsoftwares\anaconda\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in f:\allsoftwares\anaconda\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in f:\allsoftwares\anaconda\lib\site-packages (from tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in f:\allsoftwares\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in f:\allsoftwares\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in f:\allsoftwares\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in f:\allsoftwares\anaconda\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\allsoftwares\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in f:\allsoftwares\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\allsoftwares\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in f:\allsoftwares\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in f:\allsoftwares\anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in f:\allsoftwares\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in f:\allsoftwares\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow-intel==2.14.0->tensorflow) (3.2.2)

# %%
# TensorFlow and tf.keras
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pathlib

# %%
data_dir = pathlib.Path(r"D:\Teaching Courses\HSU IT306 - Emerging Technologies (TIN321)\LABs\2025.05\T3.C2\data\Set_A\Train")
data_dir
# Out:
# WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train')

# %%
listImages = list(data_dir.glob('*/*.jpg'))

image_count = len(listImages)
print(image_count)
listImages
# Out:
# 49
# [WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/13 - Hoa oi/Hoa oi 001.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/13 - Hoa oi/Hoa oi 002.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/13 - Hoa oi/Hoa oi 003.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/13 - Hoa oi/Hoa oi 004.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/13 - Hoa oi/Hoa oi 005.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/13 - Hoa oi/Hoa oi 007.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/13 - Hoa oi/Hoa oi 009.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/13 - Hoa oi/Hoa oi 010.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/13 - Hoa oi/Hoa oi 011.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/13 - Hoa oi/Hoa oi 012.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/13 - Hoa oi/Hoa oi 013.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/13 - Hoa oi/Hoa oi 014.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/16 - Hoa ban/Hoa ban 001.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/16 - Hoa ban/Hoa ban 002.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/16 - Hoa ban/Hoa ban 003.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/16 - Hoa ban/Hoa ban 004.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/16 - Hoa ban/Hoa ban 005.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/16 - Hoa ban/Hoa ban 007.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/16 - Hoa ban/Hoa ban 008.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/16 - Hoa ban/Hoa ban 009.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/16 - Hoa ban/Hoa ban 012.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/16 - Hoa ban/Hoa ban 016.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/19 - Hoa Phao Bong/Hoa Thien Phuc 001.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/19 - Hoa Phao Bong/Hoa Thien Phuc 002.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/19 - Hoa Phao Bong/Hoa Thien Phuc 003.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/19 - Hoa Phao Bong/Hoa Thien Phuc 005.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/19 - Hoa Phao Bong/Hoa Thien Phuc 006.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/19 - Hoa Phao Bong/Hoa Thien Phuc 007.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/19 - Hoa Phao Bong/Hoa Thien Phuc 011.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/3 - Hoa mai/hoa mai 004.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/3 - Hoa mai/hoa mai 006.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/3 - Hoa mai/hoa mai 007.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/3 - Hoa mai/hoa mai 008.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/3 - Hoa mai/hoa mai 009.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/3 - Hoa mai/hoa mai 010.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/6 - Hoa do quyen/Hoa do quyen 001.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/6 - Hoa do quyen/Hoa do quyen 002.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/6 - Hoa do quyen/Hoa do quyen 003.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/6 - Hoa do quyen/Hoa do quyen 004.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/6 - Hoa do quyen/Hoa do quyen 005.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/6 - Hoa do quyen/Hoa do quyen 006.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/6 - Hoa do quyen/Hoa do quyen 007.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/6 - Hoa do quyen/Hoa do quyen 009.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/6 - Hoa do quyen/Hoa do quyen 010.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/9 - Hoa sung/Hoa sung 001.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/9 - Hoa sung/Hoa sung 002.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/9 - Hoa sung/Hoa sung 003.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/9 - Hoa sung/Hoa sung 004.jpg'),
#  WindowsPath('D:/Teaching Courses/HSU IT306 - Emerging Technologies (TIN321)/LABs/2025.05/T3.C2/data/Set_A/Train/9 - Hoa sung/Hoa sung 007.jpg')]

# %%
PIL.Image.open(str(listImages[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>

# %%
# chuẩn hóa datatset

batch_size = 16
img_height = 180
img_width = 180

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 49 files belonging to 6 classes.
# Using 40 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 49 files belonging to 6 classes.
# Using 9 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['13 - Hoa oi', '16 - Hoa ban', '19 - Hoa Phao Bong', '3 - Hoa mai', '6 - Hoa do quyen', '9 - Hoa sung']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
## Dựng Model

# output
num_classes = len(class_names)

# khai báo các Layers
model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
# tạo model ở trên

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 3989414 (15.22 MB)
# Trainable params: 3989414 (15.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 3/3 [==============================] - 3s 317ms/step - loss: 2.3896 - accuracy: 0.1750 - val_loss: 1.7975 - val_accuracy: 0.2222
# Epoch 2/10
# 3/3 [==============================] - 1s 211ms/step - loss: 1.8383 - accuracy: 0.2000 - val_loss: 1.7369 - val_accuracy: 0.2222
# Epoch 3/10
# 3/3 [==============================] - 1s 201ms/step - loss: 1.7023 - accuracy: 0.3000 - val_loss: 1.8294 - val_accuracy: 0.1111
# Epoch 4/10
# 3/3 [==============================] - 1s 201ms/step - loss: 1.6426 - accuracy: 0.2750 - val_loss: 1.9138 - val_accuracy: 0.1111
# Epoch 5/10
# 3/3 [==============================] - 1s 206ms/step - loss: 1.5236 - accuracy: 0.4250 - val_loss: 1.7717 - val_accuracy: 0.3333
# Epoch 6/10
# 3/3 [==============================] - 1s 199ms/step - loss: 1.3059 - accuracy: 0.6750 - val_loss: 1.6886 - val_accuracy: 0.2222
# Epoch 7/10
# 3/3 [==============================] - 1s 200ms/step - loss: 1.0358 - accuracy: 0.8750 - val_loss: 1.5380 - val_accuracy: 0.4444
# Epoch 8/10
# 3/3 [==============================] - 1s 196ms/step - loss: 0.6719 - accuracy: 0.8750 - val_loss: 1.3727 - val_accuracy: 0.5556
# Epoch 9/10
# 3/3 [==============================] - 1s 196ms/step - loss: 0.3935 - accuracy: 0.9250 - val_loss: 1.4025 - val_accuracy: 0.4444
# Epoch 10/10
# 3/3 [==============================] - 1s 206ms/step - loss: 0.2397 - accuracy: 0.9500 - val_loss: 1.1953 - val_accuracy: 0.5556

# %%
for i in range(10):
    img = tf.keras.utils.load_img(
        listImages[i] , target_size=(img_height, img_width)
    )
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])

    print(i,
        "Predict {} with a {:.2f} percent confidence."
        .format(class_names[np.argmax(score)], 100 * np.max(score))
        , " ::REAL" , listImages[i]
    )
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 0 Predict 13 - Hoa oi with a 99.97 percent confidence.  ::REAL D:\Teaching Courses\HSU IT306 - Emerging Technologies (TIN321)\LABs\2025.05\T3.C2\data\Set_A\Train\13 - Hoa oi\Hoa oi 001.jpg
# 1/1 [==============================] - 0s 29ms/step
# 1 Predict 13 - Hoa oi with a 98.66 percent confidence.  ::REAL D:\Teaching Courses\HSU IT306 - Emerging Technologies (TIN321)\LABs\2025.05\T3.C2\data\Set_A\Train\13 - Hoa oi\Hoa oi 002.jpg
# 1/1 [==============================] - 0s 32ms/step
# 2 Predict 13 - Hoa oi with a 58.12 percent confidence.  ::REAL D:\Teaching Courses\HSU IT306 - Emerging Technologies (TIN321)\LABs\2025.05\T3.C2\data\Set_A\Train\13 - Hoa oi\Hoa oi 003.jpg
# 1/1 [==============================] - 0s 34ms/step
# 3 Predict 13 - Hoa oi with a 96.92 percent confidence.  ::REAL D:\Teaching Courses\HSU IT306 - Emerging Technologies (TIN321)\LABs\2025.05\T3.C2\data\Set_A\Train\13 - Hoa oi\Hoa oi 004.jpg
# 1/1 [==============================] - 0s 28ms/step
# 4 Predict 13 - Hoa oi with a 99.40 percent confidence.  ::REAL D:\Teaching Courses\HSU IT306 - Emerging Technologies (TIN321)\LABs\2025.05\T3.C2\data\Set_A\Train\13 - Hoa oi\Hoa oi 005.jpg
# 1/1 [==============================] - 0s 33ms/step
# 5 Predict 13 - Hoa oi with a 98.67 percent confidence.  ::REAL D:\Teaching Courses\HSU IT306 - Emerging Technologies (TIN321)\LABs\2025.05\T3.C2\data\Set_A\Train\13 - Hoa oi\Hoa oi 007.jpg
# 1/1 [==============================] - 0s 29ms/step
# 6 Predict 13 - Hoa oi with a 84.03 percent confidence.  ::REAL D:\Teaching Courses\HSU IT306 - Emerging Technologies (TIN321)\LABs\2025.05\T3.C2\data\Set_A\Train\13 - Hoa oi\Hoa oi 009.jpg
# 1/1 [==============================] - 0s 29ms/step
# 7 Predict 13 - Hoa oi with a 99.03 percent confidence.  ::REAL D:\Teaching Courses\HSU IT306 - Emerging Technologies (TIN321)\LABs\2025.05\T3.C2\data\Set_A\Train\13 - Hoa oi\Hoa oi 010.jpg
# 1/1 [==============================] - 0s 21ms/step
# 8 Predict 13 - Hoa oi with a 97.07 percent confidence.  ::REAL D:\Teaching Courses\HSU IT306 - Emerging Technologies (TIN321)\LABs\2025.05\T3.C2\data\Set_A\Train\13 - Hoa oi\Hoa oi 011.jpg
# 1/1 [==============================] - 0s 29ms/step
# 9 Predict 13 - Hoa oi with a 99.97 percent confidence.  ::REAL D:\Teaching Courses\HSU IT306 - Emerging Technologies (TIN321)\LABs\2025.05\T3.C2\data\Set_A\Train\13 - Hoa oi\Hoa oi 012.jpg
